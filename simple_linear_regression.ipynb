# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7dfa48e4-955a-45b0-b8d1-9a69d57837c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7dfa48e4-955a-45b0-b8d1-9a69d57837c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Salary_Data.csv')
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
#import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(data['YearsExperience'])
# Out:
# <ipython-input-69-0bf0c68a1882>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['YearsExperience'])
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(data['Salary'])
# Out:
# <ipython-input-70-4005dc562572>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
import statsmodels.formula.api as smf

# %%
model=smf.ols('Salary~YearsExperience',data=data).fit()

# %%
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
model.resid
# Out:
# 0      3155.841248
# 1      8127.848783
# 2     -2236.143681
# 3     -1167.124842
# 4     -6691.117306
# 5      3444.909069
# 6      6007.912837
# 7     -1587.079627
# 8      8412.920373
# 9     -3568.060788
# 10      570.946748
# 11    -7798.049484
# 12    -6635.049484
# 13    -7456.045717
# 14    -7206.030645
# 15    -4159.015574
# 16    -7958.008038
# 17     7210.999498
# 18     -183.977895
# 19    11448.025873
# 20     1686.056015
# 21     5386.067319
# 22      855.097462
# 23    10530.108765
# 24     1424.127605
# 25    -5259.861092
# 26     1402.157748
# 27    -3876.838485
# 28     -735.812110
# 29    -3144.804574
# dtype: float64

# %%
data['predicted']=model.fittedvalues
data
# Out:
#     YearsExperience    Salary      predicted
# 0               1.1   39343.0   36187.158752
# 1               1.3   46205.0   38077.151217
# 2               1.5   37731.0   39967.143681
# 3               2.0   43525.0   44692.124842
# 4               2.2   39891.0   46582.117306
# 5               2.9   56642.0   53197.090931
# 6               3.0   60150.0   54142.087163
# 7               3.2   54445.0   56032.079627
# 8               3.2   64445.0   56032.079627
# 9               3.7   57189.0   60757.060788
# 10              3.9   63218.0   62647.053252
# 11              4.0   55794.0   63592.049484
# 12              4.0   56957.0   63592.049484
# 13              4.1   57081.0   64537.045717
# 14              4.5   61111.0   68317.030645
# 15              4.9   67938.0   72097.015574
# 16              5.1   66029.0   73987.008038
# 17              5.3   83088.0   75877.000502
# 18              5.9   81363.0   81546.977895
# 19              6.0   93940.0   82491.974127
# ...

# %%
data['error']=model.resid
data
# Out:
#     YearsExperience    Salary      predicted         error
# 0               1.1   39343.0   36187.158752   3155.841248
# 1               1.3   46205.0   38077.151217   8127.848783
# 2               1.5   37731.0   39967.143681  -2236.143681
# 3               2.0   43525.0   44692.124842  -1167.124842
# 4               2.2   39891.0   46582.117306  -6691.117306
# 5               2.9   56642.0   53197.090931   3444.909069
# 6               3.0   60150.0   54142.087163   6007.912837
# 7               3.2   54445.0   56032.079627  -1587.079627
# 8               3.2   64445.0   56032.079627   8412.920373
# 9               3.7   57189.0   60757.060788  -3568.060788
# 10              3.9   63218.0   62647.053252    570.946748
# 11              4.0   55794.0   63592.049484  -7798.049484
# 12              4.0   56957.0   63592.049484  -6635.049484
# 13              4.1   57081.0   64537.045717  -7456.045717
# 14              4.5   61111.0   68317.030645  -7206.030645
# ...

# %%
data['y']=25792.200199+(9449.962321*data['YearsExperience'])
data.head()
# Out:
#    YearsExperience   Salary     predicted        error             y
# 0              1.1  39343.0  36187.158752  3155.841248  36187.158752
# 1              1.3  46205.0  38077.151217  8127.848783  38077.151216
# 2              1.5  37731.0  39967.143681 -2236.143681  39967.143680
# 3              2.0  43525.0  44692.124842 -1167.124842  44692.124841
# 4              2.2  39891.0  46582.117306 -6691.117306  46582.117305

# %%
model.rsquared  #to find accuracy
# Out:
# 0.9569566641435086

# %%
model.pvalues
# Out:
# Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %% [markdown]
# # transformation method

# %%
data['sqrt_YearsExperience']=np.sqrt(data['YearsExperience'])
data
# Out:
#     YearsExperience    Salary      predicted         error              y  \
# 0               1.1   39343.0   36187.158752   3155.841248   36187.158752
# 1               1.3   46205.0   38077.151217   8127.848783   38077.151216
# 2               1.5   37731.0   39967.143681  -2236.143681   39967.143680
# 3               2.0   43525.0   44692.124842  -1167.124842   44692.124841
# 4               2.2   39891.0   46582.117306  -6691.117306   46582.117305
# 5               2.9   56642.0   53197.090931   3444.909069   53197.090930
# 6               3.0   60150.0   54142.087163   6007.912837   54142.087162
# 7               3.2   54445.0   56032.079627  -1587.079627   56032.079626
# 8               3.2   64445.0   56032.079627   8412.920373   56032.079626
# 9               3.7   57189.0   60757.060788  -3568.060788   60757.060787
# 10              3.9   63218.0   62647.053252    570.946748   62647.053251
# 11              4.0   55794.0   63592.049484  -7798.049484   63592.049483
# ...

# %%
model=smf.ols('Salary~sqrt_YearsExperience',data=data).fit()

# %%
model.params
# Out:
# Intercept              -16055.769117
# sqrt_YearsExperience    41500.680583
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0      27470.511884
# 1      31262.287009
# 2      34771.976586
# 3      42635.056211
# 4      45499.687794
# 5      54617.343293
# 6      55825.518202
# 7      58182.905200
# 8      58182.905200
# 9      63772.383867
# 10     65901.508208
# 11     66945.592049
# 12     66945.592049
# 13     67976.704394
# 14     71980.468875
# 15     75809.903446
# 16     77665.963118
# 17     79485.972499
# 18     84749.033766
# 19     85599.722290
# 20     92164.765553
# 21     94526.218887
# 22    100589.939171
# 23    102784.094601
# 24    106353.652306
# 25    108446.272632
# 26    111857.919142
# 27    112529.386687
# 28    117134.909368
# 29    118421.805716
# dtype: float64

# %%
model.resid
# Out:
# 0     11872.488116
# 1     14942.712991
# 2      2959.023414
# 3       889.943789
# 4     -5608.687794
# 5      2024.656707
# 6      4324.481798
# 7     -3737.905200
# 8      6262.094800
# 9     -6583.383867
# 10    -2683.508208
# 11   -11151.592049
# 12    -9988.592049
# 13   -10895.704394
# 14   -10869.468875
# 15    -7871.903446
# 16   -11636.963118
# 17     3602.027501
# 18    -3386.033766
# 19     8340.277710
# 20     -426.765553
# 21     3746.781113
# 22      712.060829
# 23    11027.905399
# 24     3077.347694
# 25    -2864.272632
# 26     5111.080858
# 27      105.613313
# 28     5256.090632
# 29     3450.194284
# dtype: float64

# %%
data['sqrt_predicted']=model.fittedvalues
data
# Out:
#     YearsExperience    Salary      predicted         error              y  \
# 0               1.1   39343.0   36187.158752   3155.841248   36187.158752
# 1               1.3   46205.0   38077.151217   8127.848783   38077.151216
# 2               1.5   37731.0   39967.143681  -2236.143681   39967.143680
# 3               2.0   43525.0   44692.124842  -1167.124842   44692.124841
# 4               2.2   39891.0   46582.117306  -6691.117306   46582.117305
# 5               2.9   56642.0   53197.090931   3444.909069   53197.090930
# 6               3.0   60150.0   54142.087163   6007.912837   54142.087162
# 7               3.2   54445.0   56032.079627  -1587.079627   56032.079626
# 8               3.2   64445.0   56032.079627   8412.920373   56032.079626
# 9               3.7   57189.0   60757.060788  -3568.060788   60757.060787
# 10              3.9   63218.0   62647.053252    570.946748   62647.053251
# 11              4.0   55794.0   63592.049484  -7798.049484   63592.049483
# ...

# %%
data['sqrt_error']=model.resid
data
# Out:
#     YearsExperience    Salary      predicted         error              y  \
# 0               1.1   39343.0   36187.158752   3155.841248   36187.158752
# 1               1.3   46205.0   38077.151217   8127.848783   38077.151216
# 2               1.5   37731.0   39967.143681  -2236.143681   39967.143680
# 3               2.0   43525.0   44692.124842  -1167.124842   44692.124841
# 4               2.2   39891.0   46582.117306  -6691.117306   46582.117305
# 5               2.9   56642.0   53197.090931   3444.909069   53197.090930
# 6               3.0   60150.0   54142.087163   6007.912837   54142.087162
# 7               3.2   54445.0   56032.079627  -1587.079627   56032.079626
# 8               3.2   64445.0   56032.079627   8412.920373   56032.079626
# 9               3.7   57189.0   60757.060788  -3568.060788   60757.060787
# 10              3.9   63218.0   62647.053252    570.946748   62647.053251
# 11              4.0   55794.0   63592.049484  -7798.049484   63592.049483
# ...

# %%
model.params
# Out:
# Intercept              -16055.769117
# sqrt_YearsExperience    41500.680583
# dtype: float64

# %%
data['sqrt_y']=-16055.769117+(41500.680583*data['sqrt_YearsExperience']+data['sqrt_error'])
data.head()
# Out:
#    YearsExperience   Salary     predicted        error             y  \
# 0              1.1  39343.0  36187.158752  3155.841248  36187.158752
# 1              1.3  46205.0  38077.151217  8127.848783  38077.151216
# 2              1.5  37731.0  39967.143681 -2236.143681  39967.143680
# 3              2.0  43525.0  44692.124842 -1167.124842  44692.124841
# 4              2.2  39891.0  46582.117306 -6691.117306  46582.117305
#
#    sqrt_YearsExperience  sqrt_predicted    sqrt_error   sqrt_y
# 0              1.048809    27470.511884  11872.488116  39343.0
# 1              1.140175    31262.287009  14942.712991  46205.0
# 2              1.224745    34771.976586   2959.023414  37731.0
# 3              1.414214    42635.056211    889.943789  43525.0
# 4              1.483240    45499.687794  -5608.687794  39891.0

# %%
model.rsquared
# Out:
# 0.9310009544993526

# %%
model.pvalues
# Out:
# Intercept               2.906965e-03
# sqrt_YearsExperience    8.565358e-18
# dtype: float64

# %% [markdown]
# # 2. **Delivery_time**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-64362f88-6671-4a08-ba79-cc6777b1ea8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64362f88-6671-4a08-ba79-cc6777b1ea8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('delivery_time.csv')
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
data.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
data.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
data.rename(columns={'Delivery Time':'Delivery_Time','Sorting Time':'Sorting_Time'},inplace=True)

# %%
import seaborn as sns
sns.distplot(data['Delivery_Time'])
# Out:
# <ipython-input-99-f1fd204f0306>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Delivery_Time'])
# <Axes: xlabel='Delivery_Time', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(data['Sorting_Time'])
# Out:
# <ipython-input-100-df10544008b5>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sorting_Time'])
# <Axes: xlabel='Sorting_Time', ylabel='Density'>

# %%
import statsmodels.formula.api as smf

# %%
model=smf.ols('Sorting_Time~Delivery_Time',data=data).fit()

# %%
model.params
# Out:
# Intercept       -0.756673
# Delivery_Time    0.413744
# dtype: float64

# %%
model.resid
# Out:
# 0     2.068057
# 1    -0.828866
# 2    -1.414763
# 3    -0.173174
# 4    -1.241892
# 5     0.405709
# 6    -0.104456
# 7    -0.173891
# 8     3.350662
# 9     1.998980
# 10    0.552137
# 11    0.308929
# 12    0.855430
# 13   -1.001378
# 14   -1.220662
# 15   -1.399832
# 16    1.067698
# 17    0.263776
# 18   -0.553276
# 19    0.379624
# 20   -3.138815
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0      7.931943
# 1      4.828866
# 2      7.414763
# 3      9.173174
# 4     11.241892
# 5      5.594291
# 6      7.104456
# 7      3.173891
# 8      6.649338
# 9      7.001020
# 10     7.447863
# 11     3.691071
# 12     6.144570
# 13     4.001378
# 14     4.220662
# 15     5.399832
# 16     4.932302
# 17     6.736224
# 18     2.553276
# 19     6.620376
# 20     8.138815
# dtype: float64

# %%
data['predicted']=model.fittedvalues
data
# Out:
#     Delivery_Time  Sorting_Time  predicted
# 0           21.00            10   7.931943
# 1           13.50             4   4.828866
# 2           19.75             6   7.414763
# 3           24.00             9   9.173174
# 4           29.00            10  11.241892
# 5           15.35             6   5.594291
# 6           19.00             7   7.104456
# 7            9.50             3   3.173891
# 8           17.90            10   6.649338
# 9           18.75             9   7.001020
# 10          19.83             8   7.447863
# 11          10.75             4   3.691071
# 12          16.68             7   6.144570
# 13          11.50             3   4.001378
# 14          12.03             3   4.220662
# 15          14.88             4   5.399832
# 16          13.75             6   4.932302
# 17          18.11             7   6.736224
# 18           8.00             2   2.553276
# 19          17.83             7   6.620376
# 20          21.50             5   8.138815

# %%
data['error']=model.resid
data
# Out:
#     Delivery_Time  Sorting_Time  predicted     error
# 0           21.00            10   7.931943  2.068057
# 1           13.50             4   4.828866 -0.828866
# 2           19.75             6   7.414763 -1.414763
# 3           24.00             9   9.173174 -0.173174
# 4           29.00            10  11.241892 -1.241892
# 5           15.35             6   5.594291  0.405709
# 6           19.00             7   7.104456 -0.104456
# 7            9.50             3   3.173891 -0.173891
# 8           17.90            10   6.649338  3.350662
# 9           18.75             9   7.001020  1.998980
# 10          19.83             8   7.447863  0.552137
# 11          10.75             4   3.691071  0.308929
# 12          16.68             7   6.144570  0.855430
# 13          11.50             3   4.001378 -1.001378
# 14          12.03             3   4.220662 -1.220662
# 15          14.88             4   5.399832 -1.399832
# 16          13.75             6   4.932302  1.067698
# ...

# %%
data['y']=-0.756673+(0.413744*data['Delivery_Time']+data['error'])
data.head()
# Out:
#    Delivery_Time  Sorting_Time  predicted     error          y
# 0          21.00            10   7.931943  2.068057  10.000008
# 1          13.50             4   4.828866 -0.828866   4.000005
# 2          19.75             6   7.414763 -1.414763   6.000008
# 3          24.00             9   9.173174 -0.173174   9.000009
# 4          29.00            10  11.241892 -1.241892  10.000011

# %%
model.rsquared
# Out:
# 0.682271474841723

# %%
model.pvalues
# Out:
# Intercept        0.512611
# Delivery_Time    0.000004
# dtype: float64

# %% [markdown]
# # log method

# %%
data['log_Delivery_Time']=np.log(data['Delivery_Time'])
data
# Out:
#     Delivery_Time  Sorting_Time  predicted     error          y  \
# 0           21.00            10   7.931943  2.068057  10.000008
# 1           13.50             4   4.828866 -0.828866   4.000005
# 2           19.75             6   7.414763 -1.414763   6.000008
# 3           24.00             9   9.173174 -0.173174   9.000009
# 4           29.00            10  11.241892 -1.241892  10.000011
# 5           15.35             6   5.594291  0.405709   6.000006
# 6           19.00             7   7.104456 -0.104456   7.000007
# 7            9.50             3   3.173891 -0.173891   3.000004
# 8           17.90            10   6.649338  3.350662  10.000007
# 9           18.75             9   7.001020  1.998980   9.000007
# 10          19.83             8   7.447863  0.552137   8.000008
# 11          10.75             4   3.691071  0.308929   4.000004
# 12          16.68             7   6.144570  0.855430   7.000007
# 13          11.50             3   4.001378 -1.001378   3.000005
# ...

# %%
model=smf.ols('Sorting_Time~log_Delivery_Time',data=data).fit()

# %%
model.params
# Out:
# Intercept           -12.499233
# log_Delivery_Time     6.735548
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0      8.007296
# 1      5.031310
# 2      7.593942
# 3      8.906703
# 4     10.181351
# 5      5.896328
# 6      7.333179
# 7      2.664452
# 8      6.931482
# 9      7.243965
# 10     7.621170
# 11     3.497060
# 12     6.456018
# 13     3.951314
# 14     4.254794
# 15     5.686869
# 16     5.154901
# 17     7.010043
# 18     1.506947
# 19     6.905090
# 20     8.165786
# dtype: float64

# %%
model.resid
# Out:
# 0     1.992704
# 1    -1.031310
# 2    -1.593942
# 3     0.093297
# 4    -0.181351
# 5     0.103672
# 6    -0.333179
# 7     0.335548
# 8     3.068518
# 9     1.756035
# 10    0.378830
# 11    0.502940
# 12    0.543982
# 13   -0.951314
# 14   -1.254794
# 15   -1.686869
# 16    0.845099
# 17   -0.010043
# 18    0.493053
# 19    0.094910
# 20   -3.165786
# dtype: float64

# %%
data['log_predicted']=model.fittedvalues
data
# Out:
#     Delivery_Time  Sorting_Time  predicted     error          y  \
# 0           21.00            10   7.931943  2.068057  10.000008
# 1           13.50             4   4.828866 -0.828866   4.000005
# 2           19.75             6   7.414763 -1.414763   6.000008
# 3           24.00             9   9.173174 -0.173174   9.000009
# 4           29.00            10  11.241892 -1.241892  10.000011
# 5           15.35             6   5.594291  0.405709   6.000006
# 6           19.00             7   7.104456 -0.104456   7.000007
# 7            9.50             3   3.173891 -0.173891   3.000004
# 8           17.90            10   6.649338  3.350662  10.000007
# 9           18.75             9   7.001020  1.998980   9.000007
# 10          19.83             8   7.447863  0.552137   8.000008
# 11          10.75             4   3.691071  0.308929   4.000004
# 12          16.68             7   6.144570  0.855430   7.000007
# 13          11.50             3   4.001378 -1.001378   3.000005
# ...

# %%
data['log_error']=model.resid
data
# Out:
#     Delivery_Time  Sorting_Time  predicted     error          y  \
# 0           21.00            10   7.931943  2.068057  10.000008
# 1           13.50             4   4.828866 -0.828866   4.000005
# 2           19.75             6   7.414763 -1.414763   6.000008
# 3           24.00             9   9.173174 -0.173174   9.000009
# 4           29.00            10  11.241892 -1.241892  10.000011
# 5           15.35             6   5.594291  0.405709   6.000006
# 6           19.00             7   7.104456 -0.104456   7.000007
# 7            9.50             3   3.173891 -0.173891   3.000004
# 8           17.90            10   6.649338  3.350662  10.000007
# 9           18.75             9   7.001020  1.998980   9.000007
# 10          19.83             8   7.447863  0.552137   8.000008
# 11          10.75             4   3.691071  0.308929   4.000004
# 12          16.68             7   6.144570  0.855430   7.000007
# 13          11.50             3   4.001378 -1.001378   3.000005
# ...

# %%
data['log_y']=-12.499233+(6.735548*data['log_Delivery_Time']+data['log_error'])
data.head()
# Out:
#    Delivery_Time  Sorting_Time  predicted     error          y  \
# 0          21.00            10   7.931943  2.068057  10.000008
# 1          13.50             4   4.828866 -0.828866   4.000005
# 2          19.75             6   7.414763 -1.414763   6.000008
# 3          24.00             9   9.173174 -0.173174   9.000009
# 4          29.00            10  11.241892 -1.241892  10.000011
#
#    log_Delivery_Time  log_predicted  log_error     log_y
# 0           3.044522       8.007296   1.992704  9.999998
# 1           2.602690       5.031310  -1.031310  3.999999
# 2           2.983153       7.593942  -1.593942  5.999998
# 3           3.178054       8.906703   0.093297  8.999998
# 4           3.367296      10.181351  -0.181351  9.999998

# %%
model.rsquared
# Out:
# 0.7109478980584186

# %%
model.pvalues
# Out:
# Intercept            0.000222
# log_Delivery_Time    0.000002
# dtype: float64
